# %%
# Import packages
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn import tree

from sklearn import metrics
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler, NearMiss
from collections import Counter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12252/975630720.py in <module>
#      15 import seaborn as sns
#      16
# ---> 17 from imblearn.over_sampling import RandomOverSampler, SMOTE
#      18 from imblearn.under_sampling import RandomUnderSampler, NearMiss
#      19 from collections import Counter
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
# pip install -U imbalanced-learn
# Out:
# Requirement already up-to-date: imbalanced-learn in c:\users\65924\anaconda\lib\site-packages (0.9.1)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\65924\anaconda\lib\site-packages (from imbalanced-learn) (2.1.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.17.3 in c:\users\65924\anaconda\lib\site-packages (from imbalanced-learn) (1.23.3)
# Requirement already satisfied, skipping upgrade: scikit-learn>=1.1.0 in c:\users\65924\anaconda\lib\site-packages (from imbalanced-learn) (1.1.3)
# Requirement already satisfied, skipping upgrade: joblib>=1.0.0 in c:\users\65924\anaconda\lib\site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied, skipping upgrade: scipy>=1.3.2 in c:\users\65924\anaconda\lib\site-packages (from imbalanced-learn) (1.9.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('../combined_profile.csv')
# df.info()
df['status']= df['status'].apply(lambda x:x.strip())
df['gender']= df['gender'].apply(lambda x:x.strip())
df
# Out:
#              username  age      occupation    status  gender  \
# 0           sandralee   19         student    single  female
# 1            dayana16   19      estudiante    single  female
# 2               Denn_   19      Estudiante    single  female
# 3          Gabrielita   19      Estudiante    single  female
# 4           Luisa5401   19      Estudiante    single  female
# ...               ...  ...             ...       ...     ...
# 7929   devortedman900   69        Engineer     widow    male
# 7930        antonie07   71   self employed  divorced    male
# 7931      wesleyclary   72        military     widow    male
# 7932      charitywork   73   self-employed     widow  female
# 7933         jimmy438   74   self employed     widow    male
#
#                                       filtered sentence  y
# 0     Im really chill person looking someone chill I...  0
# 1     white Bisexual Other nonsmoker occasional drin...  0
# 2     hispanic Bisexual Atheist nonsmoker never Fun ...  0
# 3     hispanic Bisexual Christian nonsmoker never Se...  0
# 4     hispanic Straight Other nonsmoker never Fun Fr...  0
# ...                                                 ... ..
# 7929  I told I great sense humour judge I would desc...  1
# 7930  I determined cheerful happy whatever situation...  1
# 7931  Yea loving caring man honest fault always loya...  1
# 7932           good investor good heart help needy poor  1
# 7933  Im man likes take road less traveled I enjoy l...  1
#
# [7934 rows x 7 columns]

# %%
df['y'].value_counts()
# Out:
# 0    5275
# 1    2659
# Name: y, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['occupation'].unique().tolist()
# Out:
# ['student',
#  'estudiante',
#  'Estudiante',
#  'Student',
#  'Estudio',
#  'Gerente',
#  'Estudiante de Derecho',
#  'Unemployed',
#  'Educator',
#  'ESTUDIO',
#  'Camarera',
#  'Manicurista',
#  'Universitaria',
#  'Niñera',
#  'Estudios',
#  'Independiente',
#  'Estudiar',
#  'Manager',
#  'secretaria',
#  'Plomero',
#  'Contador',
#  'Salesman',
#  'Emprendedora',
#  'Estudiando',
#  'Trabajo',
#  'Enfermera',
#  'Clerk',
#  'Waitress',
#  'Estudiante universitario',
#  'Construction',
#  'Baker',
#  'Self Employed',
#  'Ama de casa',
#  'Comerciante',
#  'maestra',
#  'Ingeniero',
#  'Administradora de empresas',
#  'Teacher',
#  'Tecnico',
#  'Secretaria',
#  'Oficina',
#  'Barbero',
#  'Estudio y trabajo',
#  'Esteticista',
#  'Journalist',
#  'Nurse',
#  'Customer service',
#  'Landscaping',
#  'Maestra',
#  'Atención al cliente',
#  'Pintor',
#  'Chef',
#  'Barista',
#  'Futbolista',
#  'Laboro',
#  'Estilista',
#  'Construccion',
#  'Musico',
#  'ESTUDIANTE',
#  'Electricista',
#  'Lawyer',
#  'Universidad',
#  'Periodistas',
#  'Nursing',
#  'military',
#  'Digitador',
#  'cajera',
#  'Engineer',
#  'Conductor',
#  'Guarda de seguridad',
#  'Universitario',
#  'Cocina',
#  'Management',
#  'Empresario',
#  'Enfermero',
#  'Music producer',
#  'Transporte',
#  'Uber',
#  'Ayudante',
#  'Paralegal',
#  'Cocinera',
#  'Contabilidad',
#  'Law',
#  'Cocinero',
#  'Freelance',
#  'Empresas',
#  'Abogado',
#  'obrero',
#  'carpintero',
#  'Sailor',
#  'English teacher',
#  'Propio',
#  'Mercadeo',
#  'No job',
#  'CSR',
#  'Driver',
#  'Employed',
#  'Administrador',
#  'ingeniero',
#  'Trabajo independiente',
#  'Oficinista',
#  'Ingeniero mecanico',
#  'IT',
#  'Retail',
#  'Cashier',
#  'Constructor',
#  'Electric',
#  'Emprendedor',
#  'Asesora',
#  'No trabajo',
#  'Periodista',
#  'Electricidad',
#  'Chofer',
#  'Sales',
#  'Ingeniero Industrial',
#  'Call center',
#  'Asistente',
#  'Independientemente',
#  'contador',
#  'Abogada',
#  'Docente',
#  'Recepcionista',
#  'Social worker',
#  'trabajo y estudio',
#  'Entrenador',
#  'Hotel',
#  'Agricultor',
#  'Mechanical engineer',
#  'Cajera',
#  'Profesora',
#  'Ing. Industrial',
#  'INDEPENDIENTE',
#  'Contractor',
#  'Guardia de seguridad',
#  'Laborer',
#  'Owner',
#  'General Contractor',
#  'Entrepreneur',
#  'EMPRESARIO',
#  'Negocio propio',
#  'Mecanico',
#  'Artista',
#  'Dentista',
#  'Policia',
#  'Deportista',
#  'Cajero',
#  'Militar',
#  'administrativo',
#  'Factory Worker',
#  'Panadero',
#  'chef',
#  'Graphic designer',
#  'odontologo',
#  'Profesor',
#  'Educador',
#  'Ingeniera',
#  'STUDENT',
#  'Obrero',
#  'Informatica',
#  'Asesor comercial',
#  'Carpintero',
#  'Comunicadora',
#  'Desempleado',
#  'civil engineer',
#  'Administradora',
#  'Amazon',
#  'Administrativo',
#  'Business owner',
#  'Ingeniero civil',
#  'Empresaria',
#  'Nanny',
#  'Desempleada',
#  'Ventas',
#  'Maestro',
#  'Escritor',
#  'DOCENTE',
#  'Retired',
#  'Trabajo Independiente',
#  'Sports',
#  'dentista',
#  'Asesor financiero',
#  'Medical',
#  'Contaduria',
#  'musico',
#  'Ingeniero industrial',
#  'Mesera',
#  'Psicologo',
#  'unemployed',
#  'Comercio',
#  'Negociante',
#  'negocio propio',
#  'ING',
#  'Ingeniero Civil',
#  'Manufacturing',
#  'INGENIERO',
#  'Ingeniera civil',
#  'Campo',
#  'farmaceutico',
#  'Vendedor',
#  'Businessman',
#  'Hvac',
#  'Marino',
#  'ADMINISTRADOR',
#  'Ing civil',
#  'emprendedor',
#  'medico',
#  'Marketing',
#  'Accountant',
#  'Oficios varios',
#  'Taxista',
#  'Vendedora',
#  'Deejay',
#  'Operator',
#  'accountant',
#  'negocio',
#  'ingeniero en sistemas',
#  'Hospitality',
#  'Escolta',
#  'teacher',
#  'Security',
#  'engineer',
#  'Oficial de seguridad',
#  'Medicine',
#  'Dentist',
#  'Engineering',
#  'self employed',
#  'Almacenista',
#  'comercio',
#  'Medico',
#  'MILITAR',
#  'Restaurant',
#  'Food service',
#  'Cook',
#  'Disabled',
#  'security',
#  'Barber',
#  'developer',
#  'Repartidor',
#  'Self employer',
#  'welder',
#  'Software engineer',
#  'Programador',
#  'Ganadero',
#  'Contadora',
#  'Agronomo',
#  'Nutricionista',
#  'cantante',
#  'Operador',
#  'Desarrollador de Software',
#  'Mesero',
#  'ingeniero civil',
#  'Ing',
#  'Operario',
#  'enfermero',
#  'Agricultura',
#  'Doctor',
#  'Asistente administrativo',
#  'Freelancer',
#  'ingeniera',
#  'Administrador de empresa',
#  'Licenciado',
#  'Sawmill worker',
#  'Publicista',
#  'profesora',
#  'University Lecturer',
#  'Bodega',
#  'Waiter',
#  'Comunicador Social',
#  'Guardia',
#  'Economista',
#  'Agente de ventas',
#  'Fedex',
#  'Truck driver',
#  'agricultor',
#  'trader',
#  'software engineer',
#  'Bartender',
#  'Artist',
#  'Carpenter',
#  'Accounting',
#  'Pharmacist',
#  'Electrician',
#  'Painter',
#  'Fotografo',
#  'Contratista',
#  'Mechanic',
#  'ama de casa',
#  'Sub chef',
#  'tecnico',
#  'Farmer',
#  'Turismo',
#  'contruccion',
#  'Hoteleria',
#  'Publicidad',
#  'Fitter',
#  'Administrador de empresas',
#  'Ing industrial',
#  'Supervisor',
#  'Architect',
#  'Foreman',
#  'Soldador',
#  'comerciante',
#  'Comercial',
#  'Ingeniero de Sistemas',
#  'Real estate agent',
#  'Administrator',
#  'Handyman',
#  'Arquitecto',
#  'manager',
#  'Receptionist',
#  'Surveyor',
#  'journalist',
#  'nurse',
#  'Software Engineer',
#  'Installer',
#  'Fisioterapeuta',
#  'Ayudante de cocina',
#  'docente',
#  'Business',
#  'administradora',
#  'policia',
#  'Military',
#  'Ambientalista',
#  'mecanico',
#  'TEACHER',
#  'Barman',
#  'abogada',
#  'electricista',
#  'Veterinaria',
#  'Craftsman',
#  'Jardinero',
#  'Welder',
#  'Cosmetologa',
#  'Ing. Sistemas',
#  'Technician',
#  'Constructor civil',
#  'Cuenta propia',
#  'Cheff',
#  'Self employed',
#  'Medical doctor',
#  'independiente',
#  'Secretary',
#  'Project manager',
#  'Personal trainer',
#  'Consultant',
#  'freelancer',
#  'Asesor de ventas',
#  'Trailero',
#  'Ingeniero Informatico',
#  'Auxiliar contable',
#  'vendedor',
#  'Seguridad',
#  'Lic. Derecho',
#  'CFO',
#  'Negocios',
#  'Tour guide',
#  'Financiero',
#  'secretary',
#  'CONSTRUCCION',
#  'Camarero',
#  'Inversionista',
#  'Recursos humanos',
#  'Construction superintendent',
#  'Pequeño empresario',
#  'publicidad',
#  'Business Administrator',
#  'Maintenance',
#  'Electromecanico',
#  'selfemployed',
#  'Educadora',
#  'Researcher',
#  'abogado',
#  'It',
#  'Designer',
#  'Care worker',
#  'Officer',
#  'Assistant',
#  'Ninguna',
#  'construction',
#  'Finance',
#  'funcionario',
#  'Auditor',
#  'Cosinero',
#  'profesor',
#  'Informatico',
#  'Finanzas',
#  'Ingenieer',
#  'Arquitecta',
#  'contractor',
#  'Guerrero',
#  'Machinist',
#  'administrador',
#  'Dishwasher',
#  'business',
#  'Author',
#  'Cosmetology',
#  'Interpreter',
#  'Dependienta',
#  'negocios',
#  'conductor',
#  'Consultor',
#  'Carpinter',
#  'Banker',
#  'Asistente dental',
#  'Stay at home mom',
#  'Data Analyst',
#  'CONTADOR',
#  'Ingeniero Mecanico',
#  'Ejecutivo',
#  'Software developer',
#  'Forklift operator',
#  'Administrative',
#  'Own bussines',
#  'Developer',
#  'Lecturer',
#  'Farmaceutica',
#  'Seguros',
#  'psicologo',
#  'Real Estate',
#  'Civil Engineer',
#  'Vigilante',
#  'ingeniero mecanico',
#  'Business Manager',
#  'Musician',
#  'Auxiliar de farmacia',
#  'Machine operator',
#  'inspector de calidad',
#  'Salud',
#  'Producer',
#  'Leyes',
#  'Traductor',
#  'Csr',
#  'Administracion',
#  'Licenciada',
#  'Casa',
#  'Negocio',
#  'A nurse',
#  'Petrolero',
#  'Ingeniero en Sistemas',
#  'Funcionario',
#  'Cobranza',
#  'IT Technician',
#  'Remodeler',
#  'technician',
#  'Concrete finisher',
#  'entrepreneur',
#  'Account Manager',
#  'diseñador',
#  'Contador publico',
#  'Truck Driver',
#  'Chapista',
#  'Financial advisor',
#  'TRABAJADOR INDEPENDIENTE',
#  'Caregiver',
#  'Campesino',
#  'admin',
#  'Sport',
#  'Writer',
#  'electrician',
#  'Trabajadora Social',
#  'Servicio al cliente',
#  'Cleaner',
#  'Assistant Manager',
#  'Information technology',
#  'Administrativa',
#  'Financista',
#  'Psicologa',
#  'Pintura',
#  'Conserje',
#  'Peluquera',
#  'Bank',
#  'PhD student',
#  'Tatuador',
#  'Photographer',
#  'Customer Service',
#  'Agente de seguridad',
#  'Trabajador independiente',
#  'MEDICO',
#  'Plumber',
#  'economist',
#  'Housekeeper',
#  'Government Worker',
#  'Medicina',
#  'Autonomo',
#  'Investigador',
#  'ventas',
#  'Legal',
#  'Ing mecanico',
#  'Director',
#  'pintor',
#  'Housekeeping',
#  'Trabajo por mi cuenta',
#  'trabajo independiente',
#  'informatica',
#  'Contruccion',
#  'Operaria',
#  'Medic',
#  'Sales rep',
#  'Health care',
#  'Veterinario',
#  'Operario de bodega',
#  'Beauty',
#  'CEO',
#  'Telecomunicaciones',
#  'merchant',
#  'Office worker',
#  'High school teacher',
#  'contador publico',
#  'Material handler',
#  'Labor',
#  'Piloto',
#  'Security officer',
#  'empresario',
#  'Ing Industrial',
#  'chofer',
#  'supervisor',
#  'Quimico',
#  'self-employed',
#  'Business Owner',
#  'Self-employed',
#  'Realtor',
#  'Ingeniero de sistemas',
#  'Contador Publico',
#  'Self',
#  'Empleado publico',
#  'FARMACEUTA',
#  'Ing. Agronomo',
#  'Remodelacion',
#  'Auxiliar administrativo',
#  'Truckdriver',
#  'Detailer',
#  'Service',
#  'Asesor Comercial',
#  'Homemaker',
#  'Sales Manager',
#  'Comunicador social',
#  'Masajista',
#  'arquitecto',
#  'Pilot',
#  'Gobierno',
#  'Logistics',
#  'Healthcare',
#  'Education',
#  'businessman',
#  'Tech',
#  'Ejecutiva de ventas',
#  'Roofer',
#  'Hogar',
#  'Technical support',
#  'Economist',
#  'Tattoo artist',
#  'Programmer',
#  'Music',
#  'Dealer',
#  'Diseñador',
#  'Massage therapist',
#  'Admin',
#  'Higher Education',
#  'Management Consultant',
#  'marketing',
#  'Ingeniero electronico',
#  'Technical',
#  'Muebles',
#  'Janitor',
#  'Empleado',
#  'ABOGADO',
#  'Operations Manager',
#  'Banca',
#  'Engineer Electronic',
#  'MAESTRA',
#  'Sistemas',
#  'Artesano',
#  'Mantenimiento',
#  'autónomo',
#  'Retail Manager',
#  'Electronic',
#  'Administration',
#  'Translator',
#  'Tourist Guide',
#  'Automotive',
#  'Insurance',
#  'superior',
#  'Topografo',
#  'driver',
#  'turismo',
#  'licenciada',
#  'Transportista',
#  'bartender',
#  'Warehouse',
#  'Retirado',
#  'Self employed contractor',
#  'Project Manager',
#  'Social Worker',
#  'sales',
#  'Probation Officer',
#  'Web Designer',
#  'Therapist',
#  'teacher of English',
#  'ARQUITECTO',
#  'Camionero',
#  'Investor',
#  'Asistente Administrativo',
#  'Funcionario publico',
#  'Own business',
#  'Hotel manager',
#  'Terapista',
#  'Cowboy',
#  'Executive',
#  'Technology',
#  'Teaching',
#  'Transportation',
#  'contratista',
#  'Control de calidad',
#  'salud',
#  'business owner',
#  'Computer',
#  'Autónomo',
#  'Jubilado',
#  'Analista',
#  'EMPELADO PUBLICO',
#  'Arquitectura',
#  'Asistente de oficina',
#  'Disability',
#  'Comunicadora Social',
#  'LAWYER',
#  'health',
#  'managing director',
#  'RN',
#  'Asistente administrativa',
#  'CNA',
#  'Administrador de Empresas',
#  'Physician',
#  'farmer',
#  'truck driver',
#  'Government',
#  'Courier',
#  'Ingeniero agronomo',
#  'Auxiliar de enfermería',
#  'government',
#  'construccion',
#  'Seller',
#  'Pensionada',
#  'medical',
#  'Counselor',
#  'COMERCIANTE',
#  'Psychotherapist',
#  'Medical assistant',
#  'Information Technology',
#  'Bus Driver',
#  'Computer Engineer',
#  'Contable',
#  'ing sistemas',
#  'carpenter',
#  'retired',
#  'lawyer',
#  'Health Care',
#  'GERENTE COMERCIAL',
#  'transport',
#  'Financial services',
#  'cna',
#  'Industrial Engineer',
#  'DJ',
#  'Retired nurse',
#  'servidor publico',
#  'Bookkeeper',
#  'Agricultural Contractor',
#  'Chemist',
#  'Retire',
#  'unemployment',
#  'Trader',
#  'Gerencia',
#  'Medico Veterinario',
#  'Militar retirado',
#  'CPA',
#  'educator',
#  'Asesor',
#  'Business Administration',
#  'administrator',
#  'consultant',
#  'Bus driver',
#  'Tutor',
#  'Funcionaria',
#  'Bibliotecaria',
#  'Bussines',
#  'airline pilot',
#  'Transport',
#  'Ing. Civil',
#  'graphic designer',
#  'autonomo',
#  'Horticulturist',
#  'Free lance',
#  'Jubilada',
#  'artista',
#  'Pensionado',
#  'maestro',
#  'Builder',
#  'Tecnico electronico',
#  'salesman',
#  'Scientist',
#  'retirado',
#  'jubilado',
#  'hospitality',
#  'management',
#  'Semi-retired',
#  'Gestor',
#  'Dietary aide',
#  'IT Project Manager',
#  'Artesana',
#  'self employed.',
#  'Salud Mental',
#  'jubilada',
#  'semi-retired',
#  'Financial Advisor',
#  'RETIRED',
#  'pensionada',
#  'company owner',
#  'Pensioner',
#  'JUBILADO',
#  'Retirada',
#  'pensioner',
#  'sastre',
#  ' doctor',
#  ' student',
#  ' self-employed',
#  ' modeling',
#  ' Accountant',
#  ' engineer',
#  ' self employed',
#  ' military',
#  ' artist',
#  ' hairstylist',
#  ' consultant',
#  ' model',
#  ' secretary',
#  ' banker',
#  ' nurse',
#  ' nursing',
#  ' teacher',
#  ' Management',
#  ' trade',
#  ' sales',
#  ' Travel Agent',
#  ' Sales Marketing',
#  ' fashion',
#  ' business',
#  ' modelling',
#  ' Beautician',
#  ' medical assistant',
#  ' worker',
#  ' waitress',
#  ' Fashion Designer',
#  ' Administrative',
#  ' architect',
#  ' nanny',
#  ' beautician',
#  ' Business owner',
#  ' seller',
#  ' Self-employed',
#  ' Military Army',
#  ' Self Employed',
#  ' sale',
#  ' Designer',
#  ' selfemployed',
#  ' marketing',
#  ' Stylist',
#  ' education',
#  ' stylist',
#  ' bank manager',
#  ' trader',
#  ' trading',
#  ' engineering',
#  ' fashion designer',
#  ' professional',
#  ' service',
#  ' Primary school teacher',
#  ' economist',
#  ' self employ',
#  ' marketer',
#  ' Fashion designer',
#  ' hair stylist',
#  ' Teacher',
#  ' civil engineer',
#  ' clerk',
#  ' self',
#  ' real estate',
#  ' military army',
#  ' military service',
#  ' Sales and marketing',
#  ' manager',
#  ' Business',
#  ' Pediatrician',
#  ' Hair stylist',
#  ' Trader',
#  ' self employee',
#  ' Hair Stylist',
#  ' Hairstylist',
#  ' finance',
#  ' Self employed',
#  ' army',
#  ' accountant',
#  ' medical or finance',
#  ' Self-Employed',
#  ' construction',
#  ' financial consultant',
#  ' cashier',
#  ' Hair dresser',
#  ' business lady',
#  ' Entrepreneur',
#  ' banking',
#  ' self employment',
#  ' Real Estate',
#  ' Business woman',
#  ' sales girl',
#  ' healthcare',
#  ' Civil Engineer',
#  ' art',
#  ' sales manager',
#  ' Engineer',
#  ' goverment',
#  ' sales person',
#  ' freelancer',
#  ' chef',
#  ' Marketing',
#  ' Hairdresser',
#  ' soldier',
#  ' Military',
#  ' Military doctor',
#  ' social worker',
#  ' Business lady',
#  ' event planner',
#  ' beauty',
#  ' Sales and Marketing',
#  ' enginner',
#  ' cook',
#  ' Technician',
#  ' Medical Nurse',
#  ' Administration',
#  ' government',
#  ' buying and selling',
#  ' Militry',
#  ' consulting',
#  ' lawyer',
#  ' Military Nurse',
#  ' civil engineering',
#  ' Geologist',
#  ' executive',
#  ' Marine Engineering',
#  ' Chemical supplier',
#  ' US Army',
#  ' medical doctor',
#  ' management',
#  ' contractor',
#  ' shopkeeper',
#  ' business owner',
#  ' Sales manager',
#  ' construction engineer',
#  ' navy',
#  ' Architecture',
#  ' Contractor',
#  ' business man',
#  ' us army',
#  ' realtor',
#  ' businessman',
#  ' Construction',
#  ' medical',
#  ' Medical Doctor',
#  ' Selfemployed',
#  ' US army',
#  ' surgeon',
#  ' Business man',
#  ' Mechanical Engineer',
#  ' Project Manager',
#  ' make up artist',
#  ' Building engineer',
#  ' architecture',
#  ' Government',
#  ' force',
#  ' Finance',
#  ' Sales/Marketing',
#  ' business woman',
#  ' Business Owner',
#  ' Petroleum Engineer',
#  ' retired',
#  ' Architect',
#  ' Project Management',
#  ' surveyor',
#  ' Executive',
#  ' own business',
#  ' Doctor',
#  ' engineer or military',
#  ' Medical',
#  ' Independent Contractor',
#  ' Marine Engineer',
#  ' Construction Engineer',
#  ' Civil Engineering',
#  ' building contractor',
#  ' militery',
#  ' Military officer',
#  ' Underground Mining',
#  ' Building Contractor',
#  ' Engineering',
#  ' project manager',
#  ' barrister',
#  ' construction engineering',
#  ' Mechanical Engineering',
#  ' Chemical Engineering',
#  ' u.s army',
#  ' Manager',
#  ' Military man',
#  ' Telecommunications',
#  ' general contractor',
#  ' service man',
#  ' Surgeon',
#  ' Self Employ',
#  ' military doctor',
#  ' Civil engineering',
#  ' geologist',
#  ' Construction Engineering',
#  ' marine engineer',
#  ' legal',
#  ' Medical doctor',
#  ' civil servant',
#  ' Structural Engineer',
#  ' sailor',
#  ' oil and gas engineer',
#  ' civil service',
#  ' militry',
#  ' Building contractor',
#  ' Building Construction',
#  ' military or construction',
#  ' construction contractor',
#  ' Project manager',
#  ' Marine engineer',
#  ' officer',
#  ' administrative',
#  ' sales / marketing',
#  ' Military Doctor',
#  ' drilling offshore',
#  ' United Nations',
#  ' captain',
#  ' Army General',
#  ' Sailor',
#  ' Retired',
#  ' Petroleum Engineering',
#  ' Self employer',
#  ' seaman',
#  ' United State Army']

# %%
df['occupation'].value_counts()
# Out:
#  military           346
#  self employed      271
#  student            262
#  engineer           209
# Estudiante          164
#                    ...
# Electric              2
#  civil servant        2
# Deportista            2
# Carpinter             2
#  Sales/Marketing      1
# Name: occupation, Length: 947, dtype: int64

# %%
# label encoding for status and gender columns
labelencoder = LabelEncoder()
df[['status_encoded','gender_encoded']]=df[['status','gender']].apply(labelencoder.fit_transform)

# %%
# binning for age column
bins=[18,34,48,60,95]
label=['18-34','35-48','49-60','61-85']
df['age_group']= pd.qcut(df['age'],4)

# %%
# label encoding for age column
df['age_group_encoded'] = labelencoder.fit_transform(df['age_group'])

# %%
df['age_group_encoded'].value_counts()
# Out:
# 0    2130
# 2    1963
# 1    1941
# 3    1900
# Name: age_group_encoded, dtype: int64

# %%
# features
X = df.loc[:,['status_encoded','gender_encoded','age_group_encoded']]
X.sample(10)
# Out:
#       status_encoded  gender_encoded  age_group_encoded
# 7027               0               1                  2
# 6845               4               1                  2
# 5563               4               0                  0
# 3156               4               1                  2
# 2215               4               1                  1
# 2                  4               0                  0
# 2598               4               1                  1
# 935                4               0                  0
# 7387               6               1                  3
# 7297               4               1                  3

# %%
df[df['status']=='married']
# Out:
#        username  age     occupation   status  gender  \
# 58      Jon2511   22        Trabajo  married    male
# 624     Gabby29   29   Construccion  married    male
# 746    Dominate   30       Mechanic  married    male
# 757    Enriiqer   30  Independiente  married    male
# 828    Ritore85   30      Comercial  married    male
# ...         ...  ...            ...      ...     ...
# 4905  coolalone   62       Business  married    male
# 4909    Macadoo   62        retired  married    male
# 5014      Anjie   64      Paralegal  married  female
# 5152  John29903   68          Sales  married    male
# 5223    VXX2020   72        Retired  married    male
#
#                                       filtered sentence  y  status_encoded  \
# 58    native american Bisexual Other nonsmoker never...  0               2
# 624   hispanic Straight Other nonsmoker occasional d...  0               2
# 746        mixed Straight Christian nonsmoker never Fun  0               2
# 757   hispanic Straight Christian chain smoker socia...  0               2
# 828   hispanic Straight Christian nonsmoker never Fu...  0               2
# ...                                                 ... ..             ...
# 4905  I trusted honest loving caring earth love trav...  0               2
# 4909                  Love outdoor animals playing golf  0               2
# 5014  white Straight Other nonsmoker occasional drin...  0               2
# 5152  Youll laugh sense humor contagious Friends des...  0               2
# 5223  Retired electrical engineer graduated high sch...  0               2
#
#       gender_encoded       age_group  age_group_encoded
# 58                 1  (17.999, 33.0]                  0
# 624                1  (17.999, 33.0]                  0
# 746                1  (17.999, 33.0]                  0
# 757                1  (17.999, 33.0]                  0
# 828                1  (17.999, 33.0]                  0
# ...              ...             ...                ...
# 4905               1    (51.0, 85.0]                  3
# 4909               1    (51.0, 85.0]                  3
# 5014               0    (51.0, 85.0]                  3
# 5152               1    (51.0, 85.0]                  3
# 5223               1    (51.0, 85.0]                  3
#
# [70 rows x 11 columns]

# %%
df.iloc[345]['status']
# Out:
# 'single'

# %%
# target
y = df["y"]

# %%
# split into training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.6, random_state=99)

# %% [markdown]
# <h3> Random Under Sampling<h3>

# %%
# random under sampling
rus = RandomUnderSampler(random_state=42)
X_train_rus, y_train_rus= rus.fit_resample(X_train, y_train)

# %%
# initialise Decision Tree
clf = DecisionTreeClassifier(criterion='entropy',random_state=99) 

# train model
clf.fit(X_train_rus, y_train_rus)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=99)

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.6142676767676768, 0.9375, 'X[0] <= 4.5\nentropy = 1.0\nsamples = 2144\nvalue = [1072, 1072]'),
#  Text(0.35984848484848486, 0.8125, 'X[1] <= 0.5\nentropy = 0.981\nsamples = 1782\nvalue = [1036, 746]'),
#  Text(0.18181818181818182, 0.6875, 'X[2] <= 1.5\nentropy = 0.975\nsamples = 711\nvalue = [290, 421]'),
#  Text(0.10101010101010101, 0.5625, 'X[2] <= 0.5\nentropy = 0.884\nsamples = 585\nvalue = [177, 408]'),
#  Text(0.06060606060606061, 0.4375, 'X[0] <= 3.5\nentropy = 0.752\nsamples = 399\nvalue = [86, 313]'),
#  Text(0.04040404040404041, 0.3125, 'X[0] <= 0.5\nentropy = 0.998\nsamples = 19\nvalue = [10, 9]'),
#  Text(0.020202020202020204, 0.1875, 'entropy = 0.946\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.06060606060606061, 0.1875, 'X[0] <= 2.0\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.04040404040404041, 0.0625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08080808080808081, 0.0625, 'entropy = 0.863\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.08080808080808081, 0.3125, 'entropy = 0.722\nsamples = 380\nvalue = [76, 304]'),
#  Text(0.1414141414141414, 0.4375, 'X[0] <= 3.5\nentropy = 1.0\nsamples = 186\nvalue = [91, 95]'),
#  Text(0.12121212121212122, 0.3125, 'X[0] <= 0.5\nentropy = 0.849\nsamples = 40\nvalue = [29, 11]'),
#  Text(0.10101010101010101, 0.1875, 'entropy = 0.988\nsamples = 23\nvalue = [13, 10]'),
#  Text(0.1414141414141414, 0.1875, 'X[0] <= 2.5\nentropy = 0.323\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.12121212121212122, 0.0625, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.16161616161616163, 0.0625, 'entropy = 0.391\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.16161616161616163, 0.3125, 'entropy = 0.984\nsamples = 146\nvalue = [62, 84]'),
#  Text(0.26262626262626265, 0.5625, 'X[0] <= 3.5\nentropy = 0.479\nsamples = 126\nvalue = [113, 13]'),
#  Text(0.2222222222222222, 0.4375, 'X[2] <= 2.5\nentropy = 0.261\nsamples = 68\nvalue = [65, 3]'),
#  Text(0.20202020202020202, 0.3125, 'X[0] <= 0.5\nentropy = 0.414\nsamples = 36\nvalue = [33, 3]'),
#  Text(0.18181818181818182, 0.1875, 'entropy = 0.529\nsamples = 25\nvalue = [22, 3]'),
#  Text(0.2222222222222222, 0.1875, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.24242424242424243, 0.3125, 'entropy = 0.0\nsamples = 32\nvalue = [32, 0]'),
#  Text(0.30303030303030304, 0.4375, 'X[2] <= 2.5\nentropy = 0.663\nsamples = 58\nvalue = [48, 10]'),
#  Text(0.2828282828282828, 0.3125, 'entropy = 0.503\nsamples = 36\nvalue = [32, 4]'),
#  Text(0.32323232323232326, 0.3125, 'entropy = 0.845\nsamples = 22\nvalue = [16, 6]'),
#  Text(0.5378787878787878, 0.6875, 'X[2] <= 1.5\nentropy = 0.885\nsamples = 1071\nvalue = [746, 325]'),
#  Text(0.43434343434343436, 0.5625, 'X[0] <= 0.5\nentropy = 0.567\nsamples = 464\nvalue = [402, 62]'),
#  Text(0.3838383838383838, 0.4375, 'X[2] <= 0.5\nentropy = 0.981\nsamples = 43\nvalue = [25, 18]'),
#  Text(0.36363636363636365, 0.3125, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.40404040404040403, 0.3125, 'entropy = 0.984\nsamples = 40\nvalue = [23, 17]'),
#  Text(0.48484848484848486, 0.4375, 'X[2] <= 0.5\nentropy = 0.483\nsamples = 421\nvalue = [377, 44]'),
#  Text(0.4444444444444444, 0.3125, 'X[0] <= 3.5\nentropy = 0.295\nsamples = 192\nvalue = [182, 10]'),
#  Text(0.42424242424242425, 0.1875, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.46464646464646464, 0.1875, 'entropy = 0.311\nsamples = 179\nvalue = [169, 10]'),
#  Text(0.5252525252525253, 0.3125, 'X[0] <= 3.5\nentropy = 0.606\nsamples = 229\nvalue = [195, 34]'),
#  Text(0.5050505050505051, 0.1875, 'X[0] <= 2.5\nentropy = 0.196\nsamples = 33\nvalue = [32, 1]'),
#  Text(0.48484848484848486, 0.0625, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.5252525252525253, 0.0625, 'entropy = 0.25\nsamples = 24\nvalue = [23, 1]'),
#  Text(0.5454545454545454, 0.1875, 'entropy = 0.654\nsamples = 196\nvalue = [163, 33]'),
#  Text(0.6414141414141414, 0.5625, 'X[0] <= 0.5\nentropy = 0.987\nsamples = 607\nvalue = [344, 263]'),
#  Text(0.5858585858585859, 0.4375, 'X[2] <= 2.5\nentropy = 0.996\nsamples = 234\nvalue = [108, 126]'),
#  Text(0.5656565656565656, 0.3125, 'entropy = 0.924\nsamples = 112\nvalue = [38, 74]'),
#  Text(0.6060606060606061, 0.3125, 'entropy = 0.984\nsamples = 122\nvalue = [70, 52]'),
#  Text(0.696969696969697, 0.4375, 'X[0] <= 3.5\nentropy = 0.949\nsamples = 373\nvalue = [236, 137]'),
#  Text(0.6464646464646465, 0.3125, 'X[2] <= 2.5\nentropy = 0.312\nsamples = 89\nvalue = [84, 5]'),
#  Text(0.6060606060606061, 0.1875, 'X[0] <= 2.5\nentropy = 0.144\nsamples = 49\nvalue = [48, 1]'),
#  Text(0.5858585858585859, 0.0625, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.6262626262626263, 0.0625, 'entropy = 0.169\nsamples = 40\nvalue = [39, 1]'),
#  Text(0.6868686868686869, 0.1875, 'X[0] <= 2.5\nentropy = 0.469\nsamples = 40\nvalue = [36, 4]'),
#  Text(0.6666666666666666, 0.0625, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.7070707070707071, 0.0625, 'entropy = 0.533\nsamples = 33\nvalue = [29, 4]'),
#  Text(0.7474747474747475, 0.3125, 'X[2] <= 2.5\nentropy = 0.996\nsamples = 284\nvalue = [152, 132]'),
#  Text(0.7272727272727273, 0.1875, 'entropy = 1.0\nsamples = 175\nvalue = [88, 87]'),
#  Text(0.7676767676767676, 0.1875, 'entropy = 0.978\nsamples = 109\nvalue = [64, 45]'),
#  Text(0.8686868686868687, 0.8125, 'X[1] <= 0.5\nentropy = 0.467\nsamples = 362\nvalue = [36, 326]'),
#  Text(0.797979797979798, 0.6875, 'X[2] <= 1.5\nentropy = 0.987\nsamples = 44\nvalue = [19, 25]'),
#  Text(0.7575757575757576, 0.5625, 'X[2] <= 0.5\nentropy = 0.567\nsamples = 15\nvalue = [2, 13]'),
#  Text(0.7373737373737373, 0.4375, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.7777777777777778, 0.4375, 'entropy = 0.764\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.8383838383838383, 0.5625, 'X[2] <= 2.5\nentropy = 0.978\nsamples = 29\nvalue = [17, 12]'),
#  Text(0.8181818181818182, 0.4375, 'entropy = 0.94\nsamples = 14\nvalue = [9, 5]'),
#  Text(0.8585858585858586, 0.4375, 'entropy = 0.997\nsamples = 15\nvalue = [8, 7]'),
#  Text(0.9393939393939394, 0.6875, 'X[2] <= 2.5\nentropy = 0.301\nsamples = 318\nvalue = [17, 301]'),
#  Text(0.9191919191919192, 0.5625, 'X[2] <= 0.5\nentropy = 0.239\nsamples = 153\nvalue = [6, 147]'),
#  Text(0.898989898989899, 0.4375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9393939393939394, 0.4375, 'X[0] <= 5.5\nentropy = 0.24\nsamples = 152\nvalue = [6, 146]'),
#  Text(0.9191919191919192, 0.3125, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9595959595959596, 0.3125, 'X[2] <= 1.5\nentropy = 0.241\nsamples = 151\nvalue = [6, 145]'),
#  Text(0.9393939393939394, 0.1875, 'entropy = 0.242\nsamples = 25\nvalue = [1, 24]'),
#  Text(0.9797979797979798, 0.1875, 'entropy = 0.241\nsamples = 126\nvalue = [5, 121]'),
#  Text(0.9595959595959596, 0.5625, 'entropy = 0.353\nsamples = 165\nvalue = [11, 154]')]

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\syafi\appdata\local\programs\python\python39\lib\site-packages (0.20.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# get predictions and compare results
predictions = clf.predict(X_test)
results_df = pd.DataFrame({'Actual': y_test, 'Predicted': predictions})
results_df.sample(10)
# Out:
#       Actual  Predicted
# 2904       0          0
# 4831       0          0
# 7222       1          1
# 3736       0          0
# 6983       1          1
# 3985       0          0
# 2899       0          0
# 1733       0          0
# 1720       0          0
# 6825       1          0

# %%
# Accuracy
accuracy = accuracy_score(y_test,predictions)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.7739970594412938

# %%
# confusion matrix
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(y_test, predictions)
tn = conf_matrix[0][0]
fn = conf_matrix[1][0]
tp = conf_matrix[1][1]
fp = conf_matrix[0][1]

accuracy = (tp + tn)/(tp + tn + fn + fp)
precision = tp / (tp + fp)
recall = tp / (tp + fn)
f1_score = 2*(precision*recall)/(precision + recall)

print("random oversampling")
print("Accuracy:",accuracy)
print("Precision:",precision)
print("recall:",recall)
print("f1_score:",f1_score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23216/2360484081.py in <module>
#       1 # confusion matrix
#       2 from sklearn.metrics import confusion_matrix
# ----> 3 conf_matrix = confusion_matrix(y_test, predictions)
#       4 tn = conf_matrix[0][0]
#       5 fn = conf_matrix[1][0]
#
# NameError: name 'predictions' is not defined

# %%
from sklearn.tree import export_graphviz
import pydotplus
from six import StringIO
# from sklearn.externals.six import StringIO  
from IPython.display import Image

feature_cols = ['status_encoded', 'gender_encoded','age_group_encoded']

dot_data = StringIO()
export_graphviz(clf, out_file = dot_data, 
                      feature_names = feature_cols,  
                     filled = True, rounded = True,  
                    special_characters = True)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23216/1726519069.py in <module>
#      14
#      15 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# ---> 16 Image(graph.create_png())
#
# c:\Users\syafi\AppData\Local\Programs\Python\Python39\lib\site-packages\pydotplus\graphviz.py in <lambda>(f, prog)
#    1795             self.__setattr__(
#    1796                 'create_' + frmt,
# -> 1797                 lambda f=frmt, prog=self.prog: self.create(format=f, prog=prog)
#    1798             )
#    1799             f = self.__dict__['create_' + frmt]
#
# c:\Users\syafi\AppData\Local\Programs\Python\Python39\lib\site-packages\pydotplus\graphviz.py in create(self, prog, format)
#    1957             self.progs = find_graphviz()
#    1958             if self.progs is None:
# -> 1959                 raise InvocationException(
#    1960                     'GraphViz\'s executables not found')
#    1961
#
# InvocationException: GraphViz's executables not found

# %%
# Precision and Recall
precision = metrics.precision_score(y_test, predictions)
recall = metrics.recall_score(y_test, predictions)
f_measure = metrics.f1_score(y_test, predictions)
print("Precision:",precision)
print("Recall:",recall)
print("F-measure:",f_measure)
# Out:
# Precision: 0.7408585055643879
# Recall: 0.5872715816005041
# F-measure: 0.6551845342706503

# %%
data = [[58,'married','male']]
testdf = pd.DataFrame(data, columns=['age', 'status','gender'])
testdf['age_group_encoded'] = 3
testdf['status_encoded'] = 2
testdf['gender_encoded'] = 1
test = testdf[['status_encoded','gender_encoded','age_group_encoded']]
pred = clf.predict(test)
results = pd.DataFrame({'Pred': pred})
results
# Out:
#    Pred
# 0     0

# %% [markdown]
# Feature Enginnering

# %%
# create a copy of the dataframe
engineer_df = df.copy()
engineer_df.sample(5)
# Out:
#            username  age           occupation     status gender  \
# 3901     Marioponce   50                 Cook  separated   male
# 1084   JuanManuel19   32     Recursos humanos     single   male
# 7154    D_wehemeyer   51             military      widow   male
# 6835   Notime4games   47   Underground Mining   divorced   male
# 4156          Queno   52           Empresario   divorced   male
#
#                                       filtered sentence  y  status_encoded  \
# 3901  hispanic Straight Christian social smoker soci...  0               3
# 1084  hispanic Straight Christian nonsmoker social d...  0               4
# 7154  I Brave intelligent US Soldier I honest trustw...  1               6
# 6835  I believe life work progress There many things...  1               0
# 4156  hispanic Straight Other nonsmoker never Seriou...  0               0
#
#       gender_encoded       age_group  age_group_encoded
# 3901               1    (42.0, 51.0]                  2
# 1084               1  (17.999, 33.0]                  0
# 7154               1    (42.0, 51.0]                  2
# 6835               1    (42.0, 51.0]                  2
# 4156               1    (51.0, 85.0]                  3

# %%
# feature aggregate 
engineer_df[""] = engineer_df[""] + engineer_df[""]
engineer_df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-a78dc013be1f> in <module>
#       1 # feature aggregate
# ----> 2 engineer_df[""] = engineer_df[""] + engineer_df[""]
#       3 engineer_df.sample(5)
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''

# %% [markdown]
# Modelling Features

# %%
# Features
X = engineer_df[["",""]]
# Target
y = engineer_df[""]
X.sample(5)

# %%
# Split into training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# Decision Tree

# %%
# Train model
dt_clf = DecisionTreeClassifier(criterion='gini')  
dt_clf.fit(X_train, y_train)

# %%
feature_cols = ["",""]

dot_data = StringIO()
export_graphviz(dt_clf, out_file = dot_data, 
                      feature_names = feature_cols,  
                     filled = True, rounded = True,  
                    special_characters = True)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
# Compare results
dt_predictions = dt_clf.predict(X_test)
dt_results_df = pd.DataFrame({'Actual': y_test, 'Predicted': dt_predictions})
dt_results_df.sample(10)

# %%
# Accuracy
dt_accuracy = accuracy_score(y_test,dt_predictions)
print("Accuracy:",dt_accuracy)

# %%
# Precision and Recall
dt_precision = metrics.precision_score(y_test, dt_predictions)
dt_recall = metrics.recall_score(y_test, dt_predictions)
dt_f_measure = metrics.f1_score(y_test, dt_predictions)
print("Precision:",dt_precision)
print("Recall:",dt_recall)
print("F-measure:",dt_f_measure)

# %% [markdown]
# Decision Tree data split visulisation

# %%
groups = engineer_df.groupby("fraud")
for name, group in groups:
    plt.plot(group[""], group[""], marker="o", linestyle="", label=name)
plt.plot([9.4,9.4], [1,9], linestyle='-')
plt.plot([5,12], [1.65,1.65], linestyle='-')
plt.legend()
plt.show()
