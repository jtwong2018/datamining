# %%
import pandas as pd
import glob, os, json
import io 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
json_dir = 'data/scamprofile'
json_pattern = os.path.join(json_dir, '*.json')
file_list = glob.glob(json_pattern)

dfs = []
for file in file_list:
    with open(file) as f:
        json_data = pd.json_normalize(json.loads(f.read()))
        json_data['site'] = file.rsplit("/", 1)[-1]
    dfs.append(json_data)
scamdf = pd.concat(dfs)

# %%
scamdf['occupation'].value_counts().head(10)
# Out:
#  military         322
#  –                308
#  self employed    225
#  engineer         187
#  student          171
#  nurse             75
#  self-employed     70
#  business          62
#  contractor        53
#  Engineer          44
# Name: occupation, dtype: int64

# %%
scamdf[scamdf['description'].isnull()]
# Out:
#    year_reported month_reported           username                 name  age  \
# 0           2017             01   nathangilbert130       Nathan Gilbert   36
# 0           2015             05             keneth         Keneth Bruce   60
# 0           2016             10          josephmax           Joseph Max   56
# 0           2016             12            Esanzab              Esanzab   33
# 0           2014             02             Jhjh28        James Helmick   55
# ..           ...            ...                ...                  ...  ...
# 0           2012             11      stevencookjoe         steven brady   52
# 0           2017             01         cynthia214      Cynthia Charles   32
# 0           2017             08           ashley02          Ashley Reed   39
# 0           2016             10           Bobbydon   Ricoderek Anderson   51
# 0           2018             10        willsonbaby        Tessi Willson   29
#
#                        occupation     status              inet  \
# 0                          doctor    widowed    88.202.186.216
# 0                  civil engineer     single                 –
# 0                   Military army    widowed      41.242.136.9
# 0                            wife    married     192.36.29.100
# 0                               –          –                 –
# ..                            ...        ...               ...
# 0               plado oil company          –     78.46.238.214
# 0                           nurse     single    105.112.39.126
# 0                        Engineer   divorced   102.248.253.225
# 0    Military police at U.S. Army     single      41.246.62.28
# 0                         student     single    104.243.245.45
#
#                            email                                         tags  \
# 0    nathangilbert2442@gmail.com      [Male profiles, hangouts, love scammer]
# 0            kenbrucee@gmail.com   [Male profiles, angelreturn, love scammer]
# 0          josephmax74@gmail.com      [Male profiles, facebook, love scammer]
# 0           EsanFoodTH@unseen.is     [Female profiles, adult18.chat, spammer]
# 0            jh2000877@gmail.com                [Male profiles, fishmeetfish]
# ..                           ...                                          ...
# 0        stevencookjoe@yahoo.com        [Male profiles, love scammer, netlog]
# 0    cynthiacharles214@yahoo.com              [Female profiles, love scammer]
# 0       ashleyreed3186@gmail.com    [Female profiles, hangouts, love scammer]
# 0        bobbydonderek@yahoo.com  [Male profiles, facebook, military scammer]
# 0      gen.benhodges60@gmail.com    [Female profiles, 419 scammer, Mary Uche]
#
#     gender                                             images  \
# 0     male                            [nathangilbert1301.jpg]
# 0     male                                      [keneth1.jpg]
# 0     male                                   [josephmax1.jpg]
# 0   female                                     [Esanzab1.jpg]
# 0     male                                      [Jhjh281.jpg]
# ..     ...                                                ...
# 0     male  [stevencookjoe1.jpg, stevencookjoe2.jpg, steve...
# 0   female                 [cynthia2141.jpg, cynthia2142.jpg]
# 0   female                                    [ashley021.jpg]
# 0     male                                    [Bobbydon1.jpg]
# 0   female                                 [willsonbaby1.jpg]
#
#                          site description phone
# 0   scamnathangilbert130.json         NaN   NaN
# 0             scamkeneth.json         NaN   NaN
# 0          scamjosephmax.json         NaN   NaN
# 0            scamEsanzab.json         NaN   NaN
# 0             scamJhjh28.json         NaN   NaN
# ..                        ...         ...   ...
# 0      scamstevencookjoe.json         NaN   NaN
# 0         scamcynthia214.json         NaN   NaN
# 0           scamashley02.json         NaN   NaN
# 0           scamBobbydon.json         NaN   NaN
# 0        scamwillsonbaby.json         NaN   NaN
#
# [2987 rows x 15 columns]

# %% [markdown]
# ## Real Profiles EDA

# %%
json_dir = 'data/realprofile'
json_pattern = os.path.join(json_dir, '*.json')
file_list = glob.glob(json_pattern)

dfs = []
for file in file_list:
    with open(file) as f:
        json_data = pd.json_normalize(json.loads(f.read()))
        json_data['site'] = file.rsplit("/", 1)[-1]
    dfs.append(json_data)
realdf = pd.concat(dfs)

# %%
realdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17724 entries, 0 to 0
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   gender       17724 non-null  object
#  1   age          17724 non-null  object
#  2   location     17724 non-null  object
#  3   status       17724 non-null  object
#  4   username     17724 non-null  object
#  5   ethnicity    17724 non-null  object
#  6   occupation   17724 non-null  object
#  7   description  17724 non-null  object
#  8   match_age    17724 non-null  object
#  9   children     17724 non-null  object
#  10  orientation  17724 non-null  object
#  11  religion     17724 non-null  object
#  12  smoking      17724 non-null  object
#  13  drinking     17724 non-null  object
#  14  intent       17724 non-null  object
#  15  site         17724 non-null  object
# dtypes: object(16)
# memory usage: 2.3+ MB

# %%
stop_words = set(stopwords.words('english')) 

word_tokens = word_tokenize(example_sent)
  
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
  
filtered_sentence = []
  
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
  
print(word_tokens)
print(filtered_sentence)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/29/2m5z5b_s3298ch9l_66c_x700000gn/T/ipykernel_1416/4168751680.py in <module>
#       1 stop_words = set(stopwords.words('english'))
#       2 description = realdf['description']
# ----> 3 description.split()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'
