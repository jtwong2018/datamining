# %%
# !pip install googletrans==4.0.0rc1
# pip install pyldavis
# !pip install easynmt
# nltk.download('omw-1.4')
pd.set_option("max_colwidth", None)

# %%
import gensim
from gensim.utils import simple_preprocess
import nltk.corpus
import nltk
import pandas as pd
import gensim.corpora
from langdetect import detect
from googletrans import Translator
from nltk.corpus import stopwords
import numpy
import time

#library that contains punctuation
import string
string.punctuation
from nltk.stem import WordNetLemmatizer

#defining the object for Lemmatization
wordnet_lemmatizer = WordNetLemmatizer()

translater = Translator()

stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
data = pd.read_csv("eda/final_combined_profile.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8452 entries, 0 to 8451
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   username               8452 non-null   object
#  1   age                    8450 non-null   float64
#  2   occupation             8448 non-null   object
#  3   status                 8452 non-null   object
#  4   gender                 8452 non-null   object
#  5   filtered sentence      8452 non-null   object
#  6   Language               8452 non-null   object
#  7   y                      8452 non-null   int64
#  8   translated_occupation  8452 non-null   object
#  9   status_lem             8452 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 660.4+ KB

# %%
data['translated_occupation']= data['translated_occupation'].apply(lambda x: x.lower())
data['translated_occupation'].nunique()
data
# Out:
#           username   age       occupation    status  gender  \
# 0         123canwe  66.0          Retired    single    male
# 1      123WILFREDO  28.0       ESTUDIANTE    single    male
# 2             1907  48.0     Construction    single    male
# 3          52Jim52  70.0          Retired  divorced    male
# 4          Aaron90  28.0    Social worker    single    male
# ...            ...   ...              ...       ...     ...
# 8447   zak123hicks  36.0          soldier   widowed    male
# 8448       zarifa2  24.0          student    single  female
# 8449       zerenab  31.0  self employment    single  female
# 8450      zikki100  36.0            nurse    single  female
# 8451       zoey094  23.0          teacher    single  female
#
# ...

# %%
#defining the function to remove punctuation
def remove_punctuation(text):
    punctuationfree="".join([i for i in text if i not in string.punctuation])
    return punctuationfree

#storing the puntuation free text
data['translated_occupation']= data['translated_occupation'].apply(lambda x:remove_punctuation(x))
data['translated_occupation'].nunique()
# Out:
# 553

# %%
data['translated_occupation'].apply(lambda x:x.strip())
data
# Out:
#           username   age       occupation    status  gender  \
# 0         123canwe  66.0          Retired    single    male
# 1      123WILFREDO  28.0       ESTUDIANTE    single    male
# 2             1907  48.0     Construction    single    male
# 3          52Jim52  70.0          Retired  divorced    male
# 4          Aaron90  28.0    Social worker    single    male
# ...            ...   ...              ...       ...     ...
# 8447   zak123hicks  36.0          soldier   widowed    male
# 8448       zarifa2  24.0          student    single  female
# 8449       zerenab  31.0  self employment    single  female
# 8450      zikki100  36.0            nurse    single  female
# 8451       zoey094  23.0          teacher    single  female
#
# ...

# %%
#defining the function for lemmatization
def lemmatizer(text):
    lemm_text = wordnet_lemmatizer.lemmatize(text)
    return lemm_text

data['translated_occupation_lem']=data['translated_occupation'].apply(lambda x:lemmatizer(x))

# %%
data
# Out:
#           username   age       occupation    status  gender  \
# 0         123canwe  66.0          Retired    single    male
# 1      123WILFREDO  28.0       ESTUDIANTE    single    male
# 2             1907  48.0     Construction    single    male
# 3          52Jim52  70.0          Retired  divorced    male
# 4          Aaron90  28.0    Social worker    single    male
# ...            ...   ...              ...       ...     ...
# 8447   zak123hicks  36.0          soldier   widowed    male
# 8448       zarifa2  24.0          student    single  female
# 8449       zerenab  31.0  self employment    single  female
# 8450      zikki100  36.0            nurse    single  female
# 8451       zoey094  23.0          teacher    single  female
#
# ...

# %%
data['translated_occupation_lem'].value_counts()
# Out:
# student                     588
# engineer                    504
# self employed               445
# military                    409
# retired                     266
#                            ...
# trabajador independiente      2
# quality inspector             2
# event planner                 2
# sales consultant              1
# inversionista                 1
# Name: translated_occupation_lem, Length: 548, dtype: int64

# %%
data['translated_occupation_lem'].unique()
# Out:
# array(['retired', 'student', 'construction', 'social worker', 'executive',
#        'journalist', 'designer', 'chef', 'entrepreneur', 'medical',
#        'sale', 'service', 'author', 'engineer', 'teacher', 'care worker',
#        'collection', 'chofer', 'lawyer', 'disabled', 'it technician',
#        'self employed', 'waitress', 'manager', 'agricultural contractor',
#        'architect', 'phd student', 'marketing', 'telecommunication',
#        'health', 'selfemployed', 'tech', 'handyman', 'civil engineer',
#        'management', 'business', 'nurse', 'educator', 'engineering',
#        'airline pilot', 'artist', 'systems engineer',
#        'operations manager', 'musician', 'factory worker', 'doctor',
#        'higher education', 'restaurant', 'electrician', 'government',
#        'carpenter', 'unemployed', 'retire', 'education', 'business owner',
#        'laborer', 'welder', 'transport', 'healthcare', 'receptionist',
# ...

# %%
# data1 = pd.read_csv("data_cat_draft.csv")
# data1.drop(data1.columns.difference(['username','translated_occupation_category']), 1, inplace=True)
# data = data.merge(data1,how='left', left_on='username', right_on='username')
# data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8454 entries, 0 to 8453
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   username                        8454 non-null   object
#  1   age                             8452 non-null   float64
#  2   occupation                      8450 non-null   object
#  3   status                          8454 non-null   object
#  4   gender                          8454 non-null   object
#  5   filtered sentence               8454 non-null   object
#  6   Language                        8454 non-null   object
#  7   y                               8454 non-null   int64
#  8   translated_occupation           8454 non-null   object
#  9   status_lem                      8454 non-null   object
#  10  translated_occupation_lem       8454 non-null   object
#  11  translated_occupation_category  2050 non-null   object
# ...

# %% [markdown]
# ## Manual Categorisation

# %%
#sample of how we did manual categorisation since Topic Modelling did not work for us
for index, row in data.iterrows():
    if "student" == row['translated_occupation_category']:
        data.at[index , 'translated_occupation_category'] = "education"

# %%
#filling in those with no category with others
data['translated_occupation_category'].fillna('others',inplace=True)

# %%
data['translated_occupation_category'].nunique()
# Out:
# 20

# %%
data[data['translated_occupation_category'].isna()]['translated_occupation_lem'].unique()
# Out:
# array([], dtype=object)

# %%
data['translated_occupation_category'].value_counts()
# Out:
# self employed    1343
# education        1024
# engineer          912
# office            683
# construction      596
# military          590
# service           549
# medical           548
# manager           407
# trade             346
# retired           286
# media             209
# art               167
# government        162
# finance           150
# transport         139
# tech              119
# unemployed        108
# others             99
# science            17
# Name: translated_occupation_category, dtype: int64

# %%
data.to_csv("final_data_cleaned.csv",index=False)

# %% [markdown]
# ## Extra! Attempted Topic Modelling to Automate Categorising of Job but ineffective

# %%
topic_data = pd.read_csv("eda/final_combined_profile.csv")
topic_data.head()
# Out:
#       username   age     occupation    status gender  \
# 0     123canwe  66.0        Retired    single   male
# 1  123WILFREDO  28.0     ESTUDIANTE    single   male
# 2         1907  48.0   Construction    single   male
# 3      52Jim52  70.0        Retired  divorced   male
# 4      Aaron90  28.0  Social worker    single   male
#
#                                                                          filtered sentence  \
# 0                                                                I full fire friskier hell
# 1                   ME GUSTA CONOCER CHICAS BONDADOSAS CARIÑOSAS Y MUY FUERTES EN LA MORAL
# 2                                                         laid back earth good sense humor
# 3                                                 Retired owner aerospace consuloting firm
# 4  Hello aaron Vermont I vermont 2 years Im really fun person I like camping bone fire etc
#
#   Language  y translated_occupation status_lem
# 0       tr  0               Retired     single
# ...

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        # deacc=True removes punctuations
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))

# %%
odata_words = list(sent_to_words(topic_data['translated_occupation']))

# %%
def flatten(lis):
    flatList = []
    # Iterate with outer list
    for element in lis:
        if type(element) is list:
            # Check if type is list than iterate through the sublist
            for item in element:
                flatList.append(item)
        else:
            flatList.append(element)
    return flatList

# %%
odata_flatten = flatten(odata_words)
odata_flatten
# odata_words
print(odata_flatten[:30])
# Out:
# ['retired', 'student', 'construction', 'retired', 'social', 'worker', 'retired', 'executive', 'journalist', 'designer', 'retired', 'chef', 'entrepreneur', 'student', 'retired', 'medical', 'sales', 'service', 'author', 'engineer', 'retired', 'teacher', 'care', 'worker', 'collection', 'chofer', 'lawyer', 'engineer', 'disabled', 'it']

# %%
import gensim.corpora as corpora
# # Create Dictionary
id2word = corpora.Dictionary(odata_words)
# Create Corpus
texts = odata_words
# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]
# View
print(corpus[:1][0][:30])
# Out:
# [(0, 1)]

# %%
from pprint import pprint
# number of topics
num_topics = 10
# Build LDA model
lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                       id2word=id2word,
                                       num_topics=num_topics)
# Print the Keyword in the 10 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.098*"independent" + 0.085*"student" + 0.079*"military" + 0.039*"chef" + '
#   '0.038*"manager" + 0.035*"administrator" + 0.025*"electrician" + '
#   '0.024*"architect" + 0.017*"building" + 0.017*"selfemployed"'),
#  (1,
#   '0.187*"teacher" + 0.061*"accountant" + 0.034*"business" + '
#   '0.025*"administrative" + 0.024*"sales" + 0.024*"education" + '
#   '0.022*"military" + 0.017*"transport" + 0.017*"farmer" + 0.015*"manager"'),
#  (2,
#   '0.451*"engineer" + 0.032*"trade" + 0.027*"civil" + 0.025*"retired" + '
#   '0.025*"contador" + 0.021*"construction" + 0.019*"building" + 0.017*"driver" '
#   '+ 0.014*"marine" + 0.014*"psychologist"'),
#  (3,
#   '0.122*"retired" + 0.109*"sales" + 0.071*"technician" + 0.055*"entrepreneur" '
#   '+ 0.043*"lawyer" + 0.033*"profesor" + 0.030*"business" + 0.029*"doctor" + '
#   '0.024*"construction" + 0.019*"nurse"'),
#  (4,
#   '0.169*"military" + 0.107*"student" + 0.069*"lawyer" + 0.061*"mechanic" + '
# ...

# %%
topic_data['translated_occupation'].value_counts()
# Out:
# military            370
# student             355
# self employed       319
# engineer            263
# Engineer            236
#                    ...
# None                  2
# Cowboy                2
# event planner         2
# Inversionista         1
# sales consultant      1
# Name: translated_occupation, Length: 754, dtype: int64
