# %%
from bs4 import BeautifulSoup
import requests
import shutil

# %%
import csv

with open('urls.csv', newline='') as f:
    reader = csv.reader(f)
    urls = list(reader)

# print(urls)

# for url in urls: 
#     print(url[0])
# Out:
# [['0'], ['https://datingnmore.com/site/user/Byron13'], ['https://datingnmore.com/site/user/dansansaav'], ['https://datingnmore.com/site/user/Jvrb'], ['https://datingnmore.com/site/user/Majaz007'], ['https://datingnmore.com/site/user/camarogirl'], ['https://datingnmore.com/site/user/Andreina19'], ['https://datingnmore.com/site/user/mahervitch'], ['https://datingnmore.com/site/user/Beni1966'], ['https://datingnmore.com/site/user/Edwinrene'], ['https://datingnmore.com/site/user/pirado47'], ['https://datingnmore.com/site/user/Aba'], ['https://datingnmore.com/site/user/Antoniojoseg'], ['https://datingnmore.com/site/user/Danita5'], ['https://datingnmore.com/site/user/rv123'], ['https://datingnmore.com/site/user/Walter9001'], ['https://datingnmore.com/site/user/ginomaheu'], ['https://datingnmore.com/site/user/adriana26'], ['https://datingnmore.com/site/user/PedrodeLeon'], ['https://datingnmore.com/site/user/Aldair06'], ['https://datingnmore.com/site/user/AntMar'], ['https://datingnmore.com/site/user/Ovidio23'], ['https://datingnmore.com/site/user/Labian2001'], ['https://datingnmore.com/site/user/JhonGelvez'], ['https://datingnmore.com/site/user/Dilan29'], ['https://datingnmore.com/site/user/AlexRamos'], ['https://datingnmore.com/site/user/Mopri'], ['https://datingnmore.com/site/user/Yordan'], ['https://datingnmore.com/site/user/Victog'], ['https://datingnmore.com/site/user/Feralenam'], ['https://datingnmore.com/site/user/elvin3882'], ['https://datingnmore.com/site/user/Alinortiz'], ['https://datingnmore.com/site/user/joeform68'], ['https://datingnmore.com/site/user/Busconovia'], ['https://datingnmore.com/site/user/Karenrachel'], ['https://datingnmore.com/site/user/Vasilis47'], ['https://datingnmore.com/site/user/Fernando70'], ['https://datingnmore.com/site/user/skeila'], ['https://datingnmore.com/site/user/Louis13'], ['https://datingnmore.com/site/user/brezhnevmartinez'], ['https://datingnmore.com/site/user/Johanstone21'], ['https://datingnmore.com/site/user/juanheredia'], ['https://datingnmore.com/site/user/Natt218'], ['https://datingnmore.com/site/user/Yovanny'], ['https://datingnmore.com/site/user/Kmonge'], ['https://datingnmore.com/site/user/Xavier66'], ['https://datingnmore.com/site/user/Zach730'], ['https://datingnmore.com/site/user/Josevicebte94'], ['https://datingnmore.com/site/user/dario12'], ['https://datingnmore.com/site/user/Jerry201920'], ['https://datingnmore.com/site/user/Luis2009'], ['https://datingnmore.com/site/user/c_art'], ['https://datingnmore.com/site/user/Balfred'], ['https://datingnmore.com/site/user/Nohelia'], ['https://datingnmore.com/site/user/RalstonB'], ['https://datingnmore.com/site/user/Adripafonher'], ['https://datingnmore.com/site/user/Dayago2002'], ['https://datingnmore.com/site/user/Carolina0923'], ['https://datingnmore.com/site/user/Iveth12'], ['https://datingnmore.com/site/user/jorge89'], ['https://datingnmore.com/site/user/Soledad1111'], ['https://datingnmore.com/site/user/hector34'], ['https://datingnmore.com/site/user/LopezVega1981'], ['https://datingnmore.com/site/user/quamephilip'], ['https://datingnmore.com/site/user/Lizza'], ['https://datingnmore.com/site/user/Jhosn69'], ['https://datingnmore.com/site/user/jp31287'], ['https://datingnmore.com/site/user/Julia2410'], ['https://datingnmore.com/site/user/Lorenzobaes'], ['https://datingnmore.com/site/user/SofiaLpv2805'], ['https://datingnmore.com/site/user/Daves22'], ['https://datingnmore.com/site/user/migueltecnicotv'], ['https://datingnmore.com/site/user/Yenri19'], ['https://datingnmore.com/site/user/Ricardo68'], ['https://datingnmore.com/site/user/javier22soy'], ['https://datingnmore.com/site/user/Melyperez27'], ['https://datingnmore.com/site/user/Adelaida0404'], ['https://datingnmore.com/site/user/Chris1921'], ['https://datingnmore.com/site/user/Natalinda'], ['https://datingnmore.com/site/user/smachore'], ['https://datingnmore.com/site/user/Josetj'], ['https://datingnmore.com/site/user/ivangonzalez'], ['https://datingnmore.com/site/user/Luci ...

# %%
for url in urls: 
    html_page = requests.get(url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    warning = soup.find(id='avatar_console_image')
    img_url = warning.attrs['style'].split('background-image:')[-1][5:-2]
    username = url[0].split("user/",1)[1]
    r = requests.get(img_url, stream=True) #Get request on full_url
    if r.status_code == 200:                     #200 status code = OK
        outfile = username+'.jpg'
        try:
            with open(outfile, 'wb') as f: 
                r.raw.decode_content = True
                shutil.copyfileobj(r.raw, f)
        except Exception as e:
            print("Exception when handling {}".format(url))
            print(e)
# Out:
# ---------------------------------------------------------------------------
# LocationParseError                        Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/requests/models.py in prepare_url(self, url, params)
#     381         try:
# --> 382             scheme, auth, host, port, path, query, fragment = parse_url(url)
#     383         except LocationParseError as e:
#
# /opt/anaconda3/lib/python3.9/site-packages/urllib3/util/url.py in parse_url(url)
#     393     except (ValueError, AttributeError):
# --> 394         return six.raise_from(LocationParseError(source_url), None)
#     395
#
# /opt/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# LocationParseError: Failed to parse: ['0']
#
# During handling of the above exception, another exception occurred:
#
# InvalidURL                                Traceback (most recent call last)
# /var/folders/29/2m5z5b_s3298ch9l_66c_x700000gn/T/ipykernel_1857/1583470141.py in <module>
#       1 for url in urls:
# ----> 2     html_page = requests.get(url)
#       3     soup = BeautifulSoup(html_page.content, 'html.parser')
#       4     warning = soup.find(id='avatar_console_image')
#       5     img_url = warning.attrs['style'].split('background-image:')[-1][5:-2]
#
# /opt/anaconda3/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /opt/anaconda3/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     526             hooks=hooks,
#     527         )
# --> 528         prep = self.prepare_request(req)
#     529
#     530         proxies = proxies or {}
#
# /opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in prepare_request(self, request)
#     454
#     455         p = PreparedRequest()
# --> 456         p.prepare(
#     457             method=request.method.upper(),
#     458             url=request.url,
#
# /opt/anaconda3/lib/python3.9/site-packages/requests/models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     314
#     315         self.prepare_method(method)
# --> 316         self.prepare_url(url, params)
#     317         self.prepare_headers(headers)
#     318         self.prepare_cookies(cookies)
#
# /opt/anaconda3/lib/python3.9/site-packages/requests/models.py in prepare_url(self, url, params)
#     382             scheme, auth, host, port, path, query, fragment = parse_url(url)
#     383         except LocationParseError as e:
# --> 384             raise InvalidURL(*e.args)
#     385
#     386         if not scheme:
#
# InvalidURL: Failed to parse: ['0']
